# %%
import pandas as pd
from sqlalchemy import create_engine
file = '../data/JHS_Genotype.csv'
df=pd.read_csv(file, nrows=5)
df.to_csv('human_test_data.csv')
del df['rs_number']
df
# Out:
#   AFA1 AFA12 AFA2 AFA3 AFA4 AFA5 AFA6 AFA7 AFA8 AFA9 ...  VIET41 ZU30 ZU33  \
# 0   CT    CT   TT   CT   CT   TT   TT   TT   TT   TT ...      CC   CT   TT
# 1   AA    AA   AA   AA   AA   AA   AA   AA   AA   AA ...      AA   AA   AA
# 2   TC    TT   CC   TC   TC   TC   TC   TT   TC   CC ...      CC   NN   NN
# 3   GG    GG   GG   GG   GG   GG   GG   GG   GG   GG ...      GG   GG   GG
# 4   AA    AA   AA   AA   AA   AA   AA   AA   AA   AA ...      AA   NN   AA
#
#   ZU34 ZU35 ZU36 ZU38 ZU39 ZU41 ZU42
# 0   TT   CT   CT   CT   CT   NN   NN
# 1   NN   AC   NN   NN   NN   AC   NN
# 2   CC   CC   NN   NN   NN   CC   CC
# 3   GG   GG   GG   GG   GG   GG   GG
# 4   AG   AA   AG   AA   NN   NN   AA
#
# [5 rows x 850 columns]

# %%
from Bio import SeqIO
output_file='results.csv'

g=SeqIO.parse("micro.fa", "fasta")
data=g.__next__().seq.__str__()
data2=g.__next__().seq.__str__()
results=[data,data]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-3f97bc421790> in <module>()
#       3
#       4 g=SeqIO.parse("micro.fa", "fasta")
# ----> 5 data=g.__next__().seq.__str__()
#       6 data2=g.__next__().seq.__str__()
#       7 results=[data,data]
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/Bio/SeqIO/__init__.py in parse(handle, format, alphabet)
#     579         raise ValueError("Invalid alphabet, %r" % alphabet)
#     580
# --> 581     with as_handle(handle, mode) as fp:
#     582         # Map the file format to a sequence iterator:
#     583         if format in _FormatToIterator:
#
# /Users/nicholasrossi/anaconda/lib/python3.5/contextlib.py in __enter__(self)
#      57     def __enter__(self):
#      58         try:
# ---> 59             return next(self.gen)
#      60         except StopIteration:
#      61             raise RuntimeError("generator didn't yield") from None
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/Bio/File.py in as_handle(handleish, mode, **kwargs)
#      86                 yield fp
#      87         else:
# ---> 88             with open(handleish, mode, **kwargs) as fp:
#      89                 yield fp
#      90     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'micro.fa'

# %%
import math, string, sys, fileinput
from functools import reduce
import itertools
import numpy as np
def entropy(*X):
    return np.sum(-p * np.log2(p) if p > 0 else 0 for p in
        (np.mean(reduce(np.logical_and, (predictions == c for predictions, c in zip(X, classes))))
            for classes in itertools.product(*[set(x) for x in X])))
def range_bytes (): return range(256)
def range_printable(): return (ord(c) for c in string.printable)
def H(data, iterator=range_bytes):
    if not data:
        return 0
    entropy = 0
    for x in iterator():
        p_x = float(data.count(chr(x)))/len(data)
        if p_x > 0:
            entropy += - p_x*math.log(p_x, 2)
    return entropy

# %%
len(data2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1a3987887d63> in <module>()
# ----> 1 len(data2)
#       2
#
# NameError: name 'data2' is not defined

# %%
df.iloc[0]
# Out:
# rs_number    rs2980300
# AFA1                CT
# AFA12               CT
# AFA2                TT
# AFA3                CT
# AFA4                CT
# AFA5                TT
# AFA6                TT
# AFA7                TT
# AFA8                TT
# AFA9                TT
# AFH1                TT
# AFH10               TT
# AFH11               CT
# AFH12               TT
# AFH13               CT
# AFH15               TT
# AFH16               CT
# AFH2                TT
# AFH3                CT
# AFH4                CT
# AFH5                TT
# AFH6                CT
# AFH7                TT
# AFH8                NN
# AFH9                TT
# AFP10               TT
# AFP11               CT
# AFP12               TT
# AFP13               TT
#                ...
# URK18               CC
# URK24               CC
# URK26               CT
# URK27               CC
# URK29               CC
# URK30               CC
# URK31               CC
# URK34               CC
# URK36               CT
# URK38               CT
# URK41               CC
# URK6                CT
# URK7                CT
# URK9                CC
# VIET16              CT
# VIET19              CT
# VIET2               CT
# VIET20              CC
# VIET23              CT
# VIET4               CC
# VIET41              CC
# ZU30                CT
# ZU33                TT
# ZU34                TT
# ZU35                CT
# ZU36                CT
# ZU38                CT
# ZU39                CT
# ZU41                NN
# ZU42                NN
# Name: 0, dtype: object

# %%
file = 'axiom.txt'
df2=pd.read_table(file, sep=',',nrows=5)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-5d72f4ea5268> in <module>()
#       1 file = 'axiom.txt'
# ----> 2 df2=pd.read_table(file, sep=',',nrows=5)
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     560                     skip_blank_lines=skip_blank_lines)
#     561
# --> 562         return _read(filepath_or_buffer, kwds)
#     563
#     564     parser_f.__name__ = name
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     313
#     314     # Create the parser.
# --> 315     parser = TextFileReader(filepath_or_buffer, **kwds)
#     316
#     317     if (nrows is not None) and (chunksize is not None):
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     643             self.options['has_index_names'] = kwds['has_index_names']
#     644
# --> 645         self._make_engine(self.engine)
#     646
#     647     def close(self):
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     797     def _make_engine(self, engine='c'):
#     798         if engine == 'c':
# --> 799             self._engine = CParserWrapper(self.f, **self.options)
#     800         else:
#     801             if engine == 'python':
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1211         kwds['allow_leading_cols'] = self.index_col is not False
#    1212
# -> 1213         self._reader = _parser.TextReader(src, **kwds)
#    1214
#    1215         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3427)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:6861)()
#
# OSError: File b'axiom.txt' does not exist

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d4a59695a920> in <module>()
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
file = '../data/kasp.csv'
# df=pd.read_csv(file, nrows=40)
df=pd.read_csv(file, nrows=40)

# %%
list(df.columns.values)
# Out:
# ['Marker',
#  'Primer Allele FAM',
#  'Primer Allele VIC',
#  'Primer Common',
#  'FAM Allele ',
#  'VIC Allele',
#  'sequence',
#  'Map location AxC',
#  'cM AxC',
#  'Map location SxR',
#  'cM SxR',
#  'PIC',
#  'Co-dominant 46 varieties',
#  'Alchemy',
#  'Alcedo',
#  'Avalon',
#  'Bacannora',
#  'Brompton',
#  'Cadenza',
#  'Chinese Spring L42',
#  'Claire',
#  'Hereward',
#  'Opata',
#  'Recital',
#  'Renan',
#  'Rialto',
#  'Robigus',
#  'Savannah',
#  'Shamrock',
#  'Soissons',
#  'Synthetic',
#  'Weebil',
#  'Xi19',
#  'Diploid',
#  'Tetraploid',
#  'Synthetic 39',
#  'Apache',
#  'Battalion',
#  'Caphorn',
#  'Cappelle Desprez',
#  'Einstein',
#  'Exotic',
#  'Exsept',
#  'Gatsby',
#  'Glasgow',
#  'Gulliver',
#  'Hobbit',
#  'Humber',
#  'Longbow',
#  'Oakley',
#  'Batis ',
#  'Moulin',
#  'Oratorio ',
#  'Tuerkis ',
#  'Premio',
#  'Kofa/CAP52 durum',
#  'UC1113/Cap51 durum',
#  'Chinese Spring Ph1',
#  '24 Paragon',
#  'Solstice',
#  'L14',
#  'Oberkulmer',
#  'Forno',
#  'PI372456-Rivet',
#  'PI52503-Hati',
#  'Cltr15472-Derbazi',
#  'TRI4082-Rivet',
#  'Weebill1',
#  'Sokoll',
#  'Vorobey',
#  'Parus',
#  'PBW343',
#  'CNDO F5 SrgeneBW1R 5496',
#  'MUV',
#  'Pavon F 76',
#  'Ashby',
#  'PI192483',
#  'TRI 3055-Lobeiro',
#  'RxS BC4 NIL Iw1',
#  'XxS BC4 NIL Iw1',
#  'Cham1',
#  'Langdon',
#  'UC1112',
#  'UC1113+Lr19',
#  'Anahuac 75',
#  'BR18',
#  'GN02s',
#  'GN01r',
#  'M6Synthetic',
#  'Opata85',
#  'Yumai 34',
#  'Ukrainka',
#  'Biensur',
#  'Hoh-506-P6',
#  'Shango',
#  'Badger',
#  'Lynx',
#  'Malacca',
#  'Buster',
#  'Spark',
#  'Charger',
#  'Watkins 34',
#  'Watkins 141',
#  'Watkins 209',
#  'Watkins 292',
#  'Watkins 352',
#  'Watkins 468',
#  'Watkins 481',
#  'Watkins 729',
#  'Watkins 788',
#  'Fiorello',
#  'Hereford',
#  'Riband',
#  'Bobwhite',
#  'NIAB Paragon',
#  'TTD140 T. dicoccoides',
#  'JIC2220007 A.tauschii',
#  'A.tauschii 230',
#  'A.tauschii 323',
#  'T.uratu',
#  'A.speltoides',
#  'A.mutica',
#  'S.cereale',
#  'T.bessarabicum',
#  'T.elongatum',
#  'Watkins 126',
#  'Watkins 199',
#  'Watkins 246',
#  'Watkins 305',
#  'Watkins 471',
#  'Watkins 627',
#  'Watkins 707',
#  'Watkins 827',
#  'Hoh-501-P14',
#  'Ent 392',
#  'Ent 424',
#  'Ent 336',
#  'Ent 088',
#  'Watkins 69',
#  'Watkins 190',
#  'Watkins 238',
#  'Watkins 299',
#  'Watkins 300',
#  'Watkins 308',
#  'Watkins 444',
#  'Watkins 475',
#  'Watkins 546',
#  'Watkins 568',
#  'Watkins 731',
#  'Watkins 777',
#  'Watkins 811',
#  'Watkins 103',
#  'N7DT7B',
#  'N7BT7A',
#  'N7AT7B',
#  'N6DT6B',
#  'mt6BST6A',
#  'N6AT6B',
#  'N5DT5B',
#  'N5BT5D',
#  'N5AT5B',
#  'N4DT4B',
#  'N4BT4D',
#  'N4AT4D',
#  'N1AT1B',
#  'N1BT1A',
#  'N1DT1A',
#  'N2AT2D',
#  'N2BT2D',
#  'N2DT2A',
#  'N3AT3B',
#  'N3DT3A',
#  'Th. intermedium',
#  'Ae. caudata',
#  'CIMMYT 112',
#  'CIMMYT 251',
#  'CIMMYT 186',
#  'Synthetic 46',
#  'Option',
#  'TA2452',
#  'Watkins 629',
#  'Solstice2']

# %%
bad_names=['Marker',
 'Primer Allele FAM',
 'Primer Allele VIC',
 'Primer Common',
 'FAM Allele ',
 'VIC Allele',
 'sequence',
 'Map location AxC',
 'cM AxC',
 'Map location SxR',
 'cM SxR',
 'PIC',
 'Co-dominant 46 varieties','Unnamed: 182',
 ]
for name in bad_names:
    del df[name]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Marker'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-b6bb501266c7> in <module>()
#      14  ]
#      15 for name in bad_names:
# ---> 16     del df[name]
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    1604             # there was no match, this call should raise the appropriate
#    1605             # exception:
# -> 1606             self._data.delete(key)
#    1607
#    1608         # delete from the caches
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in delete(self, item)
#    3347         Delete selected item (items if non-unique) in-place.
#    3348         """
# -> 3349         indexer = self.items.get_loc(item)
#    3350
#    3351         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'Marker'

# %%
df
df.to_csv('wheat_test_data.csv')

# %%
results=df.iloc[3].tolist()

# %%
from collections import Counter

Counter(results)
# Out:
# Counter({'-': 30, 'A:A': 103, 'T:T': 36})

# %%
class Pmf(Counter):
    """A Counter with probabilities."""

    def normalize(self):
        """Normalizes the PMF so the probabilities add to 1."""
        total = float(sum(self.values()))
        for key in self:
            self[key] /= total

    def __add__(self, other):
        """Adds two distributions.

        The result is the distribution of sums of values from the
        two distributions.

        other: Pmf

        returns: new Pmf
        """
        pmf = Pmf()
        for key1, prob1 in self.items():
            for key2, prob2 in other.items():
                pmf[key1 + key2] += prob1 * prob2
        return pmf

    def __hash__(self):
        """Returns an integer hash value."""
        return id(self)
    
    def __eq__(self, other):
        return self is other

    def render(self):
        """Returns values and their probabilities, suitable for plotting."""
        return zip(*sorted(self.items()))

# %%
rez=Pmf(results)

# %%
rez.normalize()

# %%
print(rez)
# Out:
# Pmf({'A:A': 0.6094674556213018, 'T:T': 0.21301775147928995, '-': 0.17751479289940827})

# %%
### Entropy Calculator from List of genotypes
def H(input_list):
    rez=Pmf(input_list)
    rez.normalize()
    entropy=0
    for key, prob in rez.items():
        p_x = prob
        if p_x > 0:
            entropy += - p_x*math.log(p_x, 2)
    return entropy

# %%
results
# Out:
# ['rs307378',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'NN',
#  'GT',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'NN',
#  'GG',
#  'NN',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GT',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GT',
#  'TT',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'TT',
#  'GG',
#  'GG',
#  'GT',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GT',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'NN',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GT',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG',
#  'GG']
